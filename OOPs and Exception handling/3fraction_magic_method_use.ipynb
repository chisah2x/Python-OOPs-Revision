# %%
class Fraction:
    
    def __init__(self,  n, d):
        self.n = n
        self.d = d

        
f1 = Fraction(5, 6)
print(f1)

# %%
class Fraction:
    
    def __init__(self,  n, d):
        self.n = n
        self.d = d
    
    def __str__(self):
        return "{}/{}".format(self.n, self.d)
        
f1 = Fraction(5, 6)
print(f1)
# Out:
# 5/6

# %%
f2 = Fraction(4, 3)
print(f1+f2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8524/3263945286.py in <module>
#       1 f2 = Fraction(4, 3)
# ----> 2 print(f1+f2)
#
# TypeError: unsupported operand type(s) for +: 'Fraction' and 'Fraction'

# %% [markdown]
# ## magic method
#
# Dunder or magic methods in Python are the methods having two prefix and suffix underscores in the method name. Dunder here means “Double Under (Underscores)”. These are commonly used for operator overloading. Few examples for magic methods are: __init__, __add__, __len__, __repr__ etc.
#
# No control of user on it, it can automatically triggered
#
# ![python-magic-methods-cheat-sheet.png](attachment:python-magic-methods-cheat-sheet.png)

# %%
class Fraction:
    
    def __init__(self,  n, d):
        self.n = n
        self.d = d
    
    def __str__(self):
        return "{}/{}".format(self.n, self.d)
    
    def __add__(self, other):
        temp_n = other.n * self.d + self.n * other.d
        temp_d = other.d * self.d
        return "{}/{}".format(temp_n, temp_d)
    def __sub__(self, other):
        temp_n = other.n * self.d - self.n * other.d
        temp_d = other.d * self.d
        return "{}/{}".format(temp_n, temp_d)
    
    def __mul__(self, other):
        temp_n = other.n * self.n 
        temp_d = other.d * self.d
        return "{}/{}".format(temp_n, temp_d)
    
    def __truediv__(self, other):
        temp_n = self.n * other.d
        temp_d = other.n * self.d
        return "{}/{}".format(temp_n, temp_d)
        
f1 = Fraction(5, 6)
print(f1)
f2 = Fraction(4, 3)
print(f1+f2)
print(f1-f2)
print(f1*f2)
print(f1/f2)
# Out:
# 5/6
# 39/18
# 9/18
# 20/18
# 15/24
